# %%
# 2-1
a=80
b=75
c=55
avg=(a+b+c)/3
print(avg)
# Out:
# 70.0

# %%
# 2-2
n=13
if n%2==0:
  print("짝수")
else:
  print("홀수")
# Out:
# 홀수

# %%
# 2-3
pin="881120-1068234"
yyyymmdd=pin[0:6]
num=pin[7:]
print(yyyymmdd)
print(num)
# Out:
# 881120
# 1068234

# %%
# 2-4
pin="881120-1068234"
print(pin[7])
# Out:
# 1

# %%
# 2-5
a="a:b:c:d"
b=a.replace(':','#')
print(b)
# Out:
# a#b#c#d

# %%
# 2-6
a = [1,3,5,4,2]
a.sort()
a.reverse()
print(a)
# Out:
# [5, 4, 3, 2, 1]

# %%
# 2-7 ★
a=['Life','is','too','short']
result= " ".join(a)
print(result)
# Out:
# Life is too short

# %%
# 2-8 ★
a=(1,2,3)
a=a+(4,)
print(a)
# Out:
# (1, 2, 3, 4)

# %%
# 2-10 ★
a={'A':90,'B':80,'C':70}
result=a.pop('B')
print(a)
print(result)
# Out:
# {'A': 90, 'C': 70}
# 80

# %%
# 2-11
a=[1,1,1,2,2,3,3,3,4,4,5]
aSet=set(a)
b=list(aSet)
print(b)
# Out:
# [1, 2, 3, 4, 5]
